# %%
import re
from datetime import date
name=input("Enter your full name:-")
bdate=int(input("Enter your birth year:-"))
today=date.today()
age=today.year - bdate
print("Your age is ",age)
print()
if (age>=18):
    password=input("Enter a password:")
    flag=0
    while True:
        if (len(password)<8):
            flag=1
            break
        elif not re.search("[a-z]",password):
            flag=1
            break
        elif not re.search("[0-9]",password):
            flag=1
            break
        elif not re.search("[A-Z]",password):
            flag=1
            break
        elif not re.search("[!@#$%^&*]",password):
            flag=1
            break
        elif re.search("[\s]",password):
            flag=1
            break
        else:
            flag=0
            print("valid password")
            break
    if flag==1:
        print("invalid password")
        print()
    if flag==0:
        print("game number 1:- maths game")
        print("game number 2:- gk game")
        print()
        while True:
            try:
                game_num = int(input("Enter game number : "))
                print()
                break
            except:
                print("Invalid input")
        if(game_num==1):
            class maths_game():
                def math(self):
                    score=0
                    print("What is the only even prime number?")
                    ans=input('Enter your answer:')
                    if (ans=='2'):
                        print ("your ans is right")
                        point=10
                        score=score + point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                    print()

                    print("What is the square root of 144?")
                    ans=input('Enter your answer:')
                    if (ans=='12'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("what is square root of 2?")
                    ans=input('Enter your answer:')
                    if (ans=='4'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("What is the least common multiple of 6, 8, and 12?")
                    ans=input('Enter your answer:')
                    if (ans=='24'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("If there are 25 students in your class, but three students are absent, how many students are in the class that day?")
                    ans=input('Enter your answer:')
                    if (ans=='22'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("What is 4 times 4?")
                    ans=input('Enter your answer:')
                    if (ans=='16'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("How many sides does a hexagon have?")
                    ans=input('Enter your answer:')
                    if (ans=='6'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("How many milliliters are in one liter?")
                    ans=input('Enter your answer:')
                    if (ans=='1000'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("What is the nearest whole number to 206.86?")
                    ans=input('Enter your answer:')
                    if (ans=='207'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...Better luck next time")
                        score=score-10
                        print('Your score is:',score)
                    print()

                    print("If there are 9 chocolate bars and Chris eats 3, how many are left?")
                    ans=input('Enter your answer:')
                    if (ans=='6'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                        
                    if (score>=50):
                        print("congratulations...you are win")
                    else:
                        print("Sorry...Please try again")
            obj=maths_game()
            obj.math()
        elif (game_num == 2):
            class gk_game():
                def gk(self):
                    score=0
                    print("Rainbow consist of how many colours?")
                    ans=input('Enter your answer:')
                    if (ans=='7'):
                        
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                              
                    print("How many seconds make one hour?")
                    ans=input('Enter your answer:')
                    if (ans=='3600'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                              
                    print("How many consonants are there in the English alphabet?")
                    ans=input('Enter your answer:')
                    if (ans=='21'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                              
                    print("Name the National fruit of India?")
                    ans=input('Enter your answer:')
                    if (ans=='mango'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                              
                    print("What is the National song of India?")
                    ans=input('Enter your answer:')
                    if (ans=='vande mataram'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                        
                    print("Which is the smallest month of the year?")
                    ans=input('Enter your answer:')
                    if (ans=='february'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                        
                    print("Which colour symbolises peace?")
                    ans=input('Enter your answer:')
                    if (ans=='white'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                        
                    print("Name the largest planet of our Solar System?")
                    ans=input('Enter your answer:')
                    if (ans=='jupiter'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                        
                    print("Which festival is called the festival of colours?")
                    ans=input('Enter your answer:')
                    if (ans=='holi'):
                        print ("your ans is right")
                        point=10
                        score=score+point
                        print('Your score is:',score)
                    else:
                        print("Your answer is wrong...")
                        score=score-10
                        print('Your score is:',score)
                    print()
                    
                    if (score>=50):
                        print("congratulations...you are win")
                    else:
                        print("Sorry...Please try again")


            obj1=gk_game()
            obj1.gk()
            
        else:
            print('Invalid number...Please enter correct number')
else:
    print("Your age is below 18 you can not play game")
# Out:
# Enter your full name:-shardul
# Enter your birth year:-1999
# Your age is  23
#
# Enter a password:Shraddha@1999
# valid password
# game number 1:- maths game
# game number 2:- gk game
#
# Enter game number : 1
#
# What is the only even prime number?
# Enter your answer:2
# your ans is right
# Your score is: 10
#
# What is the square root of 144?
# Enter your answer:12
# your ans is right
# Your score is: 20
#
# what is square root of 2?
# Enter your answer:4
# your ans is right
# Your score is: 30
#
# What is the least common multiple of 6, 8, and 12?
# Enter your answer:24
# your ans is right
# Your score is: 40
#
# If there are 25 students in your class, but three students are absent, how many students are in the class that day?
# Enter your answer:22
# your ans is right
# Your score is: 50
#
# What is 4 times 4?
# Enter your answer:16
# your ans is right
# Your score is: 60
#
# How many sides does a hexagon have?
# Enter your answer:6
# your ans is right
# Your score is: 70
#
# ...
